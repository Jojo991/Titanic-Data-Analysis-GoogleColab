# %% [markdown]
# <a href="https://colab.research.google.com/github/Jojo991/Titanic-Data-Analysis-GoogleColab/blob/main/python_fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🐍 Python Fundamentals: Hands-on Exercises
#
# ## Introduction
# - Welcome to this interactive Python notebook!
# - In this series of exercises, you'll write your first lines of Python code and explore core programming concepts.
# - Each section includes a **Try This** explanation followed by a **Task** for you to complete.
#
# ## Submission Instructions
# - Fill in the code for each exercise under the **Task** section.
# - Perform the Challenge that is Exercise 32 and share the generated plots with the group.

# %% [markdown]
# ## Exercise 1: Print Statements
#
# Printing in Python allows us to display text or values. It is useful for
# outputting messages, debugging, and formatting output for users.
#
# 💡 **Tip:** You can always consult ChatGPT to explain the code and help you with the task.
#
# ### 🔹 Try This

# %%
print("Hello, world!")

# %% [markdown]
# ### 🎯 Task: Print a Greeting
# Use `print()` to display a greeting message of your choice.

# %%
# Your code here

# %% [markdown]
# ## Exercise 2: Variables
#
# Variables store values in Python, making it easy to reuse and manipulate
# data throughout a program. They can hold numbers, text, or more complex
# structures.
#
# 💡 **Tip:** You can always consult ChatGPT to explain the code and help you with the task.
#
# ### 🔹 Try This

# %%
name = "Alice"
print(name)

# %% [markdown]
# ### 🎯 Task: Create and Print a Variable
# Create a variable `city` and assign your favorite city to it, then print it.

# %%
# Your code here

# %% [markdown]
# ## Exercise 3: Data Types
#
# Python supports multiple data types, including integers, floats, and
# strings. Understanding data types helps in performing appropriate
# operations on variables.
#
# 💡 **Tip:** You can always consult ChatGPT to explain the code and help you with the task.
#
# ### 🔹 Try This

# %%
x = 10       # Integer
y = 3.14     # Float
z = "Hello"  # String

# %% [markdown]
# ### 🎯 Task: Create and Check Data Types
# Create three variables: an integer, a float, and a string, and use `type()` to check them.

# %%
# Your code here

# %% [markdown]
# ## Exercise 4: Basic Arithmetic
#
# Python can handle basic mathematical operations like addition, subtraction,
# multiplication, and division. These are essential for calculations in
# programming.
#
# 💡 **Tip:** You can always consult ChatGPT to explain the code and help you with the task.
#
# ### 🔹 Try This

# %%
sum = 5 + 3
product = 4 * 7

# %% [markdown]
# ### 🎯 Task: Calculate Perimeter
# Define variables `length` and `width`, then compute the perimeter of a rectangle.

# %%
# Your code here

# %% [markdown]
# ## Exercise 5: String Manipulation
#
# Strings in Python can be combined, modified, and formatted using various
# methods. String operations are useful for text-based applications.
#
# 💡 **Tip:** You can always consult ChatGPT to explain the code and help you with the task.
#
# ### 🔹 Try This

# %%
greeting = "Hello" + " " + "Alice"
print(greeting)

# %% [markdown]
# ### 🎯 Task: Combine Strings
# Ask for the user's first and last name and print a full name using `input()`.

# %%
# Your code here

# %% [markdown]
# ## Exercise 6: Lists
#
# Lists allow you to store multiple values in a single variable. They are
# useful for managing collections of related data efficiently.
#
# 💡 **Tip:** You can always consult ChatGPT to explain the code and help you with the task.
#
# ### 🔹 Try This

# %%
fruits = ["apple", "banana", "cherry"]
print(fruits[0])

# %% [markdown]
# ### 🎯 Task: Access List Elements
# Create a list of three favorite foods and print the first one.

# %%
# Your code here

# %% [markdown]
# ## Exercise 7: If Statements
#
# Conditional statements allow your program to make decisions. By checking
# conditions, Python can execute different code blocks based on the situation.
#
# 💡 **Tip:** You can always consult ChatGPT to explain the code and help you with the task.
#
# ### 🔹 Try This

# %%
if x > 0:
    print("Positive number")

# %% [markdown]
# ### 🎯 Task: Check Positive or Negative
# Write a program that checks if a number is positive or negative.

# %%
# Your code here

# %% [markdown]
# ## Exercise 8: Loops
#
# Loops let you repeat actions multiple times. They are useful for iterating
# over data or running code until a condition is met.
#
# 💡 **Tip:** You can always consult ChatGPT to explain the code and help you with the task.
#
# ### 🔹 Try This

# %%
for i in range(5):
    print(i)

# %% [markdown]
# ### 🎯 Task: Print Odd Numbers
# Print odd numbers from 1 to 9 using a loop.

# %%
# Write your code below:

# %% [markdown]
# ## Exercise 9: Functions
#
# Functions allow you to organize and reuse code efficiently. They take input,
# process it, and return a result, making programs more modular and readable.
#
# 💡 **Tip:** You can always consult ChatGPT to explain the code and help you with the task.
#
# ### 🔹 Try This

# %%
def greet(name):
    return "Hello " + name
print(greet("Alice"))

# %% [markdown]
# ### 🎯 Task: Define a Function to Cube
# Write a function that takes a number and returns its cube.

# %%
# Your code here

# %% [markdown]
# ## Exercise 10: Dictionaries
#
# Dictionaries store data in key-value pairs, allowing for efficient data retrieval.
#
# 💡 **Tip:** You can always consult ChatGPT to explain the code and help you with the task.
#
# ### 🔹 Try This

# %%
person = {"name": "Alice", "age": 25}
print(person["name"])

# %% [markdown]
# ### 🎯 Task: Access Dictionary Values
# Create a dictionary with three key-value pairs and print one of the keys.

# %%
# Your code here

# %% [markdown]
# ## Exercise 11: Sets
#
# Sets are collections of unique elements, useful for membership testing and eliminating duplicates.
#
# 💡 **Tip:** You can always consult ChatGPT to explain the code and help you with the task.
#
# ### 🔹 Try This

# %%
fruits = {"apple", "banana", "cherry"}
print("apple" in fruits)

# %% [markdown]
# ### 🎯 Task: Demonstrate Set Uniqueness
# Create a set of colors and demonstrate adding a duplicate color.

# %%
# Your code here

# %% [markdown]
# ## Exercise 12: Tuples
#
# Tuples are immutable sequences, often used to store related data.
#
# 💡 **Tip:** You can always consult ChatGPT to explain the code and help you with the task.
#
# ### 🔹 Try This

# %%
coordinates = (10, 20)
print(coordinates[0])

# %% [markdown]
# ### 🎯 Task: Access Tuple Elements
# Create a tuple with three elements and print the first one.

# %%
# Your code here

# %% [markdown]
# ## Exercise 13: List Comprehensions
#
# List comprehensions provide a concise way to create lists.
#
# 💡 **Tip:** You can always consult ChatGPT to explain the code and help you with the task.
#
# ### 🔹 Try This

# %%
squares = [x**2 for x in range(5)]
print(squares)

# %% [markdown]
# ### 🎯 Task: Create a List of Squares
# Create a list of squares of numbers from 0 to 4 using list comprehension.

# %%
# Your code here

# %% [markdown]
# ## Exercise 14: File I/O
#
# Python can read from and write to files, enabling data persistence.
#
# 💡 **Tip:** You can always consult ChatGPT to explain the code and help you with the task.
#
# ### 🔹 Try This

# %%
with open("example.txt", "w") as file:
    file.write("Hello, world!")

# %% [markdown]
# ### 🎯 Task: Read from a File
# Write a program that reads a list of numbers from a file and prints them.

# %%
# Your code here

# %% [markdown]
# ## Exercise 15: Exception Handling
#
# Exception handling allows you to manage errors gracefully.
#
# 💡 **Tip:** You can always consult ChatGPT to explain the code and help you with the task.
#
# ### 🔹 Try This

# %%
try:
    result = 10 / 0
except ZeroDivisionError:
    print("Cannot divide by zero")

# %% [markdown]
# ### 🎯 Task: Handle a ValueError
# Write a program that handles a ValueError when converting a string to an integer.

# %%
# Your code here

# %% [markdown]
# ## Exercise 16: NumPy Basics
#
# NumPy is a powerful library for numerical computations.
#
# 💡 **Tip:** You can always consult ChatGPT to explain the code and help you with the task.
#
# ### 🔹 Try This

# %%
import numpy as np
array = np.array([1, 2, 3])
print(array + 1)

# %% [markdown]
# ### 🎯 Task: Perform Array Operations
# Create a NumPy array and perform a subtraction operation on it.

# %%
# Your code here

# %% [markdown]
# ## Exercise 17: Matplotlib Basics
#
# Matplotlib is a library for creating static, interactive, and animated visualizations.
#
# 💡 **Tip:** You can always consult ChatGPT to explain the code and help you with the task.
#
# ### 🔹 Try This
# Plotting with Matplotlib:

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3], [4, 5, 6])
plt.show()

# %% [markdown]
# ### 🎯 Task: Plot a Bar Graph
# Use Matplotlib to plot a simple bar graph.

# %%
# Your code here

# %% [markdown]
# ## Exercise 18: Pandas Basics
#
# Pandas is a library for data manipulation and analysis.
#
# 💡 **Tip:** You can always consult ChatGPT to explain the code and help you with the task.
#
# ### 🔹 Try This
# Data manipulation with Pandas:

# %%
import pandas as pd
data = {'Name': ['Alice', 'Bob'], 'Age': [25, 30]}
df = pd.DataFrame(data)
print(df)

# %% [markdown]
# ### 🎯 Task: Manipulate a DataFrame
# Create a Pandas DataFrame and add a new column to it.

# %%
# Your code here

# %% [markdown]
# ## Exercise 19: Random Module
#
# The random module is used to generate random numbers.
#
# 💡 **Tip:** You can always consult ChatGPT to explain the code and help you with the task.
#
# ### 🔹 Try This
# Generate random numbers:

# %%
import random
print(random.randint(1, 10))

# %% [markdown]
# ### 🎯 Task: Generate a Random Float
# Write a program that generates a random float between 0 and 1.

# %%
# Your code here

# %% [markdown]
# ## Exercise 20: Time Module
#
# The time module provides various time-related functions.
#
# 💡 **Tip:** You can always consult ChatGPT to explain the code and help you with the task.
#
# ### 🔹 Try This
# Use the time module:

# %%
import time
print(time.ctime())

# %% [markdown]
# ### 🎯 Task: Delay Execution
# Write a program that delays execution for 2 seconds and then prints a message.

# %%
# Your code here

# %% [markdown]
# ## Exercise 21: Function with Multiple Parameters
#
# Functions can take multiple parameters to perform operations on them.
#
# 💡 **Tip:** You can always consult ChatGPT to explain the code and help you with the task.
#
# ### 🔹 Try This
# Define a function with multiple parameters:

# %%
def add(a, b):
    return a + b
print(add(3, 4))

# %% [markdown]
# ### 🎯 Task: Create a Function to Multiply
# Write a function that takes two numbers and returns their product.

# %%
# Your code here

# %% [markdown]
# ## Exercise 22: Default Parameters
#
# Functions can have default parameter values, which are used if no argument is provided.
#
# 💡 **Tip:** You can always consult ChatGPT to explain the code and help you with the task.
#
# ### 🔹 Try This
# Define a function with a default parameter:

# %%
def greet(name="Guest"):
    return "Hello " + name
print(greet())

# %% [markdown]
# ### 🎯 Task: Create a Function with Default Value
# Write a function that greets a user with a default name if no name is provided.

# %%
# Your code here

# %% [markdown]
# ## Exercise 23: Return Multiple Values
#
# Functions can return multiple values using tuples.
#
# 💡 **Tip:** You can always consult ChatGPT to explain the code and help you with the task.
#
# ### 🔹 Try This
# Return multiple values from a function:

# %%
def get_coordinates():
    return (10, 20)
x, y = get_coordinates()
print(x, y)

# %% [markdown]
# ### 🎯 Task: Create a Function to Return Multiple Values
# Write a function that returns the sum and product of two numbers.

# %%
# Your code here

# %% [markdown]
# ## Exercise 24: Recursive Functions
#
# A recursive function is a function that calls itself to solve a problem.
#
# 💡 **Tip:** You can always consult ChatGPT to explain the code and help you with the task.
#
# ### 🔹 Try This
# Define a recursive function:

# %%
def factorial(n):
    if n == 0:
        return 1
    else:
        return n * factorial(n-1)
print(factorial(5))

# %% [markdown]
# ### 🎯 Task: Create a Recursive Function
# Write a recursive function to calculate the Fibonacci sequence.

# %%
# Your code here

# %% [markdown]
# ## Exercise 25: Lambda Functions
#
# Lambda functions are small anonymous functions defined with the `lambda` keyword.
#
# 💡 **Tip:** You can always consult ChatGPT to explain the code and help you with the task.
#
# ### 🔹 Try This
# Define a lambda function:

# %%
square = lambda x: x * x
print(square(5))

# %% [markdown]
# ### 🎯 Task: Create a Lambda Function
# Write a lambda function to add two numbers.

# %%
# Your code here

# %% [markdown]
# ## Exercise 26: DataFrame Filtering
#
# Filtering allows you to select specific rows based on conditions.
#
# 💡 **Tip:** You can always consult ChatGPT to explain the code and help you with the task.
#
# ### 🔹 Try This
# Filter a DataFrame:

# %%
import pandas as pd
data = {'Name': ['Alice', 'Bob', 'Charlie'], 'Age': [25, 30, 35]}
df = pd.DataFrame(data)
filtered_df = df[df['Age'] > 30]
print(filtered_df)

# %% [markdown]
# ### 🎯 Task: Filter DataFrame by Multiple Conditions
# Create a DataFrame with columns for 'Name', 'Age', and 'City'. Filter the DataFrame to show only rows where 'Age' is greater than 25 and 'City' is 'New York'.

# %%
# Your code here

# %% [markdown]
# ## Exercise 27: Grouping and Aggregation
#
# Grouping and aggregation allow you to summarize data.
#
# 💡 **Tip:** You can always consult ChatGPT to explain the code and help you with the task.
#
# ### 🔹 Try This
# Group and aggregate data:

# %%
import pandas as pd
data = {'Name': ['Alice', 'Bob', 'Alice'], 'Score': [85, 90, 95]}
df = pd.DataFrame(data)
grouped = df.groupby('Name').mean()
print(grouped)

# %% [markdown]
# ### 🎯 Task: Group and Aggregate with Multiple Functions
# Create a DataFrame with 'Name', 'Score', and 'Attempts'. Group by 'Name' and calculate both the mean and sum of 'Score' for each group.

# %%
# Your code here

# %% [markdown]
# ## Exercise 28: DataFrame Merging
#
# Merging combines data from multiple DataFrames.
#
# 💡 **Tip:** You can always consult ChatGPT to explain the code and help you with the task.
#
# ### 🔹 Try This
# Merge DataFrames:

# %%
import pandas as pd
df1 = pd.DataFrame({'Name': ['Alice', 'Bob'], 'Age': [25, 30]})
df2 = pd.DataFrame({'Name': ['Alice', 'Bob'], 'Score': [85, 90]})
merged_df = pd.merge(df1, df2, on='Name')
print(merged_df)

# %% [markdown]
# ### 🎯 Task: Merge with Different Join Types
# Create two DataFrames with some overlapping and some unique 'Name' entries. Merge them using an outer join and display the result.

# %%
# Your code here

# %% [markdown]
# ## Exercise 29: Plotting with Pandas
#
# Pandas can be used to plot data directly.
#
# 💡 **Tip:** You can always consult ChatGPT to explain the code and help you with the task.
#
# ### 🔹 Try This
# Plot data with Pandas:

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = {'Year': [2010, 2011, 2012], 'Sales': [200, 250, 300]}
df = pd.DataFrame(data)
df.plot(x='Year', y='Sales', kind='line')
plt.show()

# %% [markdown]
# ### 🎯 Task: Plot Multiple Lines
# Create a DataFrame with 'Year', 'Product_A_Sales', and 'Product_B_Sales'. Plot both sales lines on the same graph with different colors.

# %%
# Your code here

# %% [markdown]
# ## Exercise 30: Advanced Plotting with Matplotlib
#
# Create complex plots using Matplotlib.
#
# 💡 **Tip:** You can always consult ChatGPT to explain the code and help you with the task.
#
# ### 🔹 Try This
# Create a subplot:

# %%
import matplotlib.pyplot as plt
fig, axs = plt.subplots(2)
axs[0].plot([1, 2, 3], [4, 5, 6])
axs[1].bar([1, 2, 3], [4, 5, 6])
plt.show()

# %% [markdown]
# ### 🎯 Task: Create a Complex Subplot
# Use Matplotlib to create a 2x2 subplot grid. Include a line plot, a bar plot, a scatter plot, and a histogram, each in a different subplot.

# %%
# Your code here

# %% [markdown]
# ## Exercise 31: Saving and Loading CSV Files
#
# CSV files are a common format for storing tabular data. Python's Pandas library makes it easy to read from and write to CSV files.
#
# 💡 **Tip:** You can always consult ChatGPT to explain the code and help you with the task.
#
# ### 🔹 Try This
# Save and load a DataFrame to/from a CSV file:

# %%
import pandas as pd

# Create a DataFrame
data = {'Name': ['Alice', 'Bob'], 'Age': [25, 30]}
df = pd.DataFrame(data)

# Save to CSV
df.to_csv('people.csv', index=False)

# Load from CSV
loaded_df = pd.read_csv('people.csv')
print(loaded_df)

# %% [markdown]
# ### 🎯 Task: Save and Load Your Data
# 1. **Create a DataFrame**: Create a DataFrame with columns 'Product', 'Price', and 'Quantity'.
# 2. **Save to CSV**: Save the DataFrame to a CSV file named `inventory.csv`.
# 3. **Load from CSV**: Load the data back into a new DataFrame and print it.
# 4. **View the CSV**: Open the `inventory.csv` file in a text editor or spreadsheet application to view its contents.

# %%
# Your code here

# %% [markdown]
# ## Exercise 32: Titanic Data Analysis Challenge
#
# In this challenge, you'll work with the Titanic dataset to perform data cleaning and analysis using Pandas.
#
# 💡 **Tip:** You can always consult ChatGPT to explain the code and help you with the task.
#
# ### 🔹 Try This
#
# ### 🎯 Task: Analyze the Titanic Dataset
# 1. **Load the [Kaggle Titanic Competition] data** into a DataFrame
# 2. **Clean the Data**: Remove rows with missing values (NaNs).
# 3. **Analyze the Data**:
#    - Calculate the survival rate by gender.
#    - Calculate the survival rate by passenger class.
#    - Calculate the average age of survivors and non-survivors.
# 4. **Visualize the Data**:
#    - Plot the survival rate by gender using a bar chart.
#    - Plot the survival rate by passenger class using a bar chart.
#    - Create a histogram of ages for survivors and non-survivors.
# 5. **Explore Further**:
#    - Plot two additional interesting insights you discover from the dataset.

# %%
import pandas as pd

# 1. Load Titanic dataset from a CSV file (you may need to specify the correct path)
titanic_data = pd.read_csv("https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv")


# Rest of Your Code here

# %%
# Importing the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Load Titanic dataset from a CSV file (using the URL provided)
titanic_data = pd.read_csv("https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv")

# 2. Display the first few rows of the dataset to understand its structure
titanic_data.head()

# 3. Clean the Data: Remove rows with missing values
titanic_cleaned = titanic_data.dropna()

# 4. Check for any missing values after cleaning
titanic_cleaned.isnull().sum()

# 5. Analyze the Data:
# Calculate the survival rate by gender
survival_rate_gender = titanic_cleaned.groupby('Sex')['Survived'].mean()

# Calculate the survival rate by passenger class
survival_rate_class = titanic_cleaned.groupby('Pclass')['Survived'].mean()

# Calculate the average age of survivors and non-survivors
average_age = titanic_cleaned.groupby('Survived')['Age'].mean()

# 6. Visualize the Data:
# Plot the survival rate by gender
plt.figure(figsize=(6, 4))
sns.barplot(x=survival_rate_gender.index, y=survival_rate_gender.values)
plt.title('Survival Rate by Gender')
plt.xlabel('Gender')
plt.ylabel('Survival Rate')
plt.show()

# Plot the survival rate by passenger class
plt.figure(figsize=(6, 4))
sns.barplot(x=survival_rate_class.index, y=survival_rate_class.values)
plt.title('Survival Rate by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Survival Rate')
plt.show()

# Create a histogram comparing the ages of survivors and non-survivors
plt.figure(figsize=(8, 5))
sns.histplot(titanic_cleaned[titanic_cleaned['Survived'] == 1]['Age'], kde=True, color='green', label='Survived', bins=30)
sns.histplot(titanic_cleaned[titanic_cleaned['Survived'] == 0]['Age'], kde=True, color='red', label='Not Survived', bins=30)
plt.title('Age Distribution of Survivors and Non-Survivors')
plt.xlabel('Age')
plt.ylabel('Frequency')  # Fixing the missing closing quotation mark
plt.legend()
plt.show()

# 7. Explore Further Insights:
# Check the column names to confirm if 'Embarked' exists
print("Column names in the dataset:", titanic_cleaned.columns)

# Plot the survival rate by embarkation location if the 'Embarked' column exists
if 'Embarked' in titanic_cleaned.columns:
    survival_rate_embarked = titanic_cleaned.groupby('Embarked')['Survived'].mean()

    plt.figure(figsize=(6, 4))
    sns.barplot(x=survival_rate_embarked.index, y=survival_rate_embarked.values)
    plt.title('Survival Rate by Embarked Location')
    plt.xlabel('Embarked Location')
    plt.ylabel('Survival Rate')
    plt.show()
else:
    print("Column 'Embarked' not found in the dataset!")

# Create age groups and calculate the survival rate for each group
age_groups = pd.cut(titanic_cleaned['Age'], bins=[0, 12, 20, 40, 60, 100], labels=['0-12', '13-20', '21-40', '41-60', '61+'])

survival_rate_age_group = titanic_cleaned.groupby(age_groups)['Survived'].mean()

plt.figure(figsize=(8, 5))
sns.barplot(x=survival_rate_age_group.index, y=survival_rate_age_group.values)
plt.title('Survival Rate by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Survival Rate')
plt.show()
# Out:
# Column names in the dataset: Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'Siblings/Spouses Aboard',
#        'Parents/Children Aboard', 'Fare'],
#       dtype='object')
# Column 'Embarked' not found in the dataset!
# <ipython-input-1-751fea361bc4>:76: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   survival_rate_age_group = titanic_cleaned.groupby(age_groups)['Survived'].mean()

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set Seaborn style
sns.set(style="whitegrid")  # This sets the background style to white with gridlines

# Load Titanic dataset from a CSV file (using the URL provided)
titanic_data = pd.read_csv("https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv")

# Clean the Data: Remove rows with missing values
titanic_cleaned = titanic_data.dropna()

# 3. Analyze the Data:
# Calculate the survival rate by gender
survival_rate_gender = titanic_cleaned.groupby('Sex')['Survived'].mean()

# Calculate the survival rate by passenger class
survival_rate_class = titanic_cleaned.groupby('Pclass')['Survived'].mean()

# Calculate the average age of survivors and non-survivors
average_age = titanic_cleaned.groupby('Survived')['Age'].mean()

# 4. Visualize the Data:
# Plot the survival rate by gender
plt.figure(figsize=(6, 4))
sns.barplot(x=survival_rate_gender.index, y=survival_rate_gender.values, palette='Set2')
plt.title('Survival Rate by Gender', fontsize=14)
plt.xlabel('Gender', fontsize=12)
plt.ylabel('Survival Rate', fontsize=12)
plt.show()

# Plot the survival rate by passenger class
plt.figure(figsize=(6, 4))
sns.barplot(x=survival_rate_class.index, y=survival_rate_class.values, palette='coolwarm')
plt.title('Survival Rate by Passenger Class', fontsize=14)
plt.xlabel('Passenger Class', fontsize=12)
plt.ylabel('Survival Rate', fontsize=12)
plt.show()

# **Age Distribution of Survivors and Non-Survivors** - IMPORTANT PLOT
plt.figure(figsize=(8, 5))
sns.histplot(titanic_cleaned[titanic_cleaned['Survived'] == 1]['Age'], kde=True, color='forestgreen', label='Survived', bins=30)
sns.histplot(titanic_cleaned[titanic_cleaned['Survived'] == 0]['Age'], kde=True, color='tomato', label='Not Survived', bins=30)
plt.title('Age Distribution of Survivors and Non-Survivors', fontsize=14)
plt.xlabel('Age', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.legend()
plt.show()

# 5. Pairplot for Selected Columns (Age, Pclass, Survived)
sns.pairplot(titanic_cleaned[['Age', 'Pclass', 'Survived']], hue='Survived', palette={0: 'tomato', 1: 'forestgreen'})
plt.suptitle('Pairplot of Age, Pclass, and Survived', fontsize=14, y=1.02)
plt.show()

# 6. Explore Further Insights:
# Check the column names to confirm if 'Embarked' exists
print("Column names in the dataset:", titanic_cleaned.columns)

# Plot the survival rate by embarkation location if the 'Embarked' column exists
if 'Embarked' in titanic_cleaned.columns:
    survival_rate_embarked = titanic_cleaned.groupby('Embarked')['Survived'].mean()

    plt.figure(figsize=(6, 4))
    sns.barplot(x=survival_rate_embarked.index, y=survival_rate_embarked.values, palette='Blues')
    plt.title('Survival Rate by Embarked Location', fontsize=14)
    plt.xlabel('Embarked Location', fontsize=12)
    plt.ylabel('Survival Rate', fontsize=12)
    plt.show()
else:
    print("Column 'Embarked' not found in the dataset!")

# Create age groups and calculate the survival rate for each group
age_groups = pd.cut(titanic_cleaned['Age'], bins=[0, 12, 20, 40, 60, 100], labels=['0-12', '13-20', '21-40', '41-60', '61+'])

survival_rate_age_group = titanic_cleaned.groupby(age_groups)['Survived'].mean()

plt.figure(figsize=(8, 5))
sns.barplot(x=survival_rate_age_group.index, y=survival_rate_age_group.values, palette='viridis')
plt.title('Survival Rate by Age Group', fontsize=14)
plt.xlabel('Age Group', fontsize=12)
plt.ylabel('Survival Rate', fontsize=12)
plt.show()
# Out:
# <ipython-input-6-ac8f1bd6172c>:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=survival_rate_gender.index, y=survival_rate_gender.values, palette='Set2')
# <ipython-input-6-ac8f1bd6172c>:36: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=survival_rate_class.index, y=survival_rate_class.values, palette='coolwarm')
# Column names in the dataset: Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'Siblings/Spouses Aboard',
#        'Parents/Children Aboard', 'Fare'],
#       dtype='object')
# Column 'Embarked' not found in the dataset!
# <ipython-input-6-ac8f1bd6172c>:77: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   survival_rate_age_group = titanic_cleaned.groupby(age_groups)['Survived'].mean()
# <ipython-input-6-ac8f1bd6172c>:80: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=survival_rate_age_group.index, y=survival_rate_age_group.values, palette='viridis')

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set Seaborn style
sns.set(style="whitegrid")  # This sets the background style to white with gridlines

# Load Titanic dataset from a CSV file (using the URL provided)
titanic_data = pd.read_csv("https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv")

# Clean the Data: Remove rows with missing values
titanic_cleaned = titanic_data.dropna()

# 3. Analyze the Data:
# Calculate the survival rate by gender
survival_rate_gender = titanic_cleaned.groupby('Sex')['Survived'].mean()

# Calculate the survival rate by passenger class
survival_rate_class = titanic_cleaned.groupby('Pclass')['Survived'].mean()

# Calculate the average age of survivors and non-survivors
average_age = titanic_cleaned.groupby('Survived')['Age'].mean()

# 4. Visualize the Data:

# **Age Distribution of Survivors and Non-Survivors** - IMPORTANT PLOT
plt.figure(figsize=(8, 5))
sns.histplot(titanic_cleaned[titanic_cleaned['Survived'] == 1]['Age'], kde=True, color='mediumseagreen', label='Survived', bins=30)
sns.histplot(titanic_cleaned[titanic_cleaned['Survived'] == 0]['Age'], kde=True, color='indianred', label='Not Survived', bins=30)
plt.title('Age Distribution of Survivors and Non-Survivors', fontsize=14)
plt.xlabel('Age', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.legend()
plt.show()

# Plot the survival rate by gender
plt.figure(figsize=(6, 4))
sns.barplot(x=survival_rate_gender.index, y=survival_rate_gender.values, palette='muted')  # More muted colors
plt.title('Survival Rate by Gender', fontsize=14)
plt.xlabel('Gender', fontsize=12)
plt.ylabel('Survival Rate', fontsize=12)
plt.show()

# Plot the survival rate by passenger class
plt.figure(figsize=(6, 4))
sns.barplot(x=survival_rate_class.index, y=survival_rate_class.values, palette='coolwarm')  # Use warm cool contrast
plt.title('Survival Rate by Passenger Class', fontsize=14)
plt.xlabel('Passenger Class', fontsize=12)
plt.ylabel('Survival Rate', fontsize=12)
plt.show()

# 5. Pairplot for Selected Columns (Age, Pclass, Survived)
sns.pairplot(titanic_cleaned[['Age', 'Pclass', 'Survived']], hue='Survived', palette={0: 'indianred', 1: 'mediumseagreen'})
plt.suptitle('Pairplot of Age, Pclass, and Survived', fontsize=14, y=1.02)
plt.show()

# 6. Explore Further Insights:
# Check the column names to confirm if 'Embarked' exists
print("Column names in the dataset:", titanic_cleaned.columns)

# Plot the survival rate by embarkation location if t
# Out:
# <ipython-input-10-875175bdf3c6>:39: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=survival_rate_gender.index, y=survival_rate_gender.values, palette='muted')  # More muted colors
# <ipython-input-10-875175bdf3c6>:47: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=survival_rate_class.index, y=survival_rate_class.values, palette='coolwarm')  # Use warm cool contrast
# Column names in the dataset: Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'Siblings/Spouses Aboard',
#        'Parents/Children Aboard', 'Fare'],
#       dtype='object')

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set Seaborn style for better aesthetics
sns.set(style="whitegrid")

# Load Titanic dataset from a CSV file (using the URL provided)
titanic_data = pd.read_csv("https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv")

# Clean the Data: Remove rows with missing values
titanic_cleaned = titanic_data.dropna()

# 1. Analyze the Data:

# Calculate the survival rate by gender
survival_rate_gender = titanic_cleaned.groupby('Sex')['Survived'].mean()

# Calculate the survival rate by passenger class
survival_rate_class = titanic_cleaned.groupby('Pclass')['Survived'].mean()

# Calculate the average age of survivors and non-survivors
average_age = titanic_cleaned.groupby('Survived')['Age'].mean()

# 2. Visualize the Data:

# **Age Distribution of Survivors and Non-Survivors**
plt.figure(figsize=(8, 5))
sns.histplot(titanic_cleaned[titanic_cleaned['Survived'] == 1]['Age'], kde=True, color='mediumseagreen', label='Survived', bins=30)
sns.histplot(titanic_cleaned[titanic_cleaned['Survived'] == 0]['Age'], kde=True, color='indianred', label='Not Survived', bins=30)
plt.title('Age Distribution of Survivors and Non-Survivors', fontsize=14)
plt.xlabel('Age', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.legend()
plt.show()

# Plot the survival rate by gender
plt.figure(figsize=(6, 4))
sns.barplot(x=survival_rate_gender.index, y=survival_rate_gender.values, palette='muted')
plt.title('Survival Rate by Gender', fontsize=14)
plt.xlabel('Gender', fontsize=12)
plt.ylabel('Survival Rate', fontsize=12)
plt.show()

# Plot the survival rate by passenger class
plt.figure(figsize=(6, 4))
sns.barplot(x=survival_rate_class.index, y=survival_rate_class.values, palette='coolwarm')
plt.title('Survival Rate by Passenger Class', fontsize=14)
plt.xlabel('Passenger Class', fontsize=12)
plt.ylabel('Survival Rate', fontsize=12)
plt.show()

# 3. Pairplot for Selected Columns (Age, Pclass, Survived)
sns.pairplot(titanic_cleaned[['Age', 'Pclass', 'Survived']], hue='Survived', palette={0: 'indianred', 1: 'mediumseagreen'})
plt.suptitle('Pairplot of Age, Pclass, and Survived', fontsize=14, y=1.02)
plt.show()

# 4. Explore Further Insights:

# Check the column names to confirm if 'Embarked' exists
print("Column names in the dataset:", titanic_cleaned.columns)

# Plot the survival rate by embarkation location if the 'Embarked' column exists
if 'Embarked' in titanic_cleaned.columns:
    survival_rate_embarked = titanic_cleaned.groupby('Embarked')['Survived'].mean()

    plt.figure(figsize=(6, 4))
    sns.barplot(x=survival_rate_embarked.index, y=survival_rate_embarked.values, palette='Blues')
    plt.title('Survival Rate by Embarked Location', fontsize=14)
    plt.xlabel('Embarked Location', fontsize=12)
    plt.ylabel('Survival Rate', fontsize=12)
    plt.show()
else:
    print("Column 'Embarked' not found in the dataset!")

# Create age groups and calculate the survival rate for each group
age_groups = pd.cut(titanic_cleaned['Age'], bins=[0, 12, 20, 40, 60, 100], labels=['0-12', '13-20', '21-40', '41-60', '61+'])

survival_rate_age_group = titanic_cleaned.groupby(age_groups)['Survived'].mean()

plt.figure(figsize=(8, 5))
sns.barplot(x=survival_rate_age_group.index, y=survival_rate_age_group.values, palette='viridis')
plt.title('Survival Rate by Age Group', fontsize=14)
plt.xlabel('Age Group', fontsize=12)
plt.ylabel('Survival Rate', fontsize=12)
plt.show()

# 5. Correlation Matrix (Heatmap)
# Select only the numeric columns for correlation analysis
numeric_columns = titanic_cleaned.select_dtypes(include=['float64', 'int64'])  # Only numeric columns

# Compute the Correlation Matrix on the numeric columns
correlation_matrix = numeric_columns.corr()  # This computes the correlation of only numerical columns

# Visualize the Correlation Matrix using a Heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5, fmt='.2f', cbar=True)
plt.title('Correlation Matrix of Titanic Dataset', fontsize=14)
plt.show()
# Out:
# <ipython-input-16-be7d20b536e8>:40: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=survival_rate_gender.index, y=survival_rate_gender.values, palette='muted')
# <ipython-input-16-be7d20b536e8>:48: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=survival_rate_class.index, y=survival_rate_class.values, palette='coolwarm')
# Column names in the dataset: Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'Siblings/Spouses Aboard',
#        'Parents/Children Aboard', 'Fare'],
#       dtype='object')
# Column 'Embarked' not found in the dataset!
# <ipython-input-16-be7d20b536e8>:80: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   survival_rate_age_group = titanic_cleaned.groupby(age_groups)['Survived'].mean()
# <ipython-input-16-be7d20b536e8>:83: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=survival_rate_age_group.index, y=survival_rate_age_group.values, palette='viridis')
